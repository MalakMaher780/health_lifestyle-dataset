# %% [markdown]
# <a href="https://colab.research.google.com/github/MalakMaher780/health_lifestyle-dataset/blob/main/Another_copy_of_Intro_to_DS_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

health_data = pd.read_csv('health_lifestyle_dataset.csv')
health_data.head()
# Out:
#    id  age  gender   bmi  daily_steps  sleep_hours  water_intake_l  \
# 0   1   56    Male  20.5         4198          3.9             3.4
# 1   2   69  Female  33.3        14359          9.0             4.7
# 2   3   46    Male  31.6         1817          6.6             4.2
# 3   4   32  Female  38.2        15772          3.6             2.0
# 4   5   60  Female  33.6         6037          3.8             4.0
#
#    calories_consumed  smoker  alcohol  resting_hr  systolic_bp  diastolic_bp  \
# 0               1602       0        0          97          161           111
# 1               2346       0        1          68          116            65
# 2               1643       0        1          90          123            99
# 3               2460       0        0          71          165            95
# 4               3756       0        1          98          139            61
#
#    cholesterol  family_history  disease_risk
# 0          240               0             0
# ...

# %%
health_data.tail()
# Out:
#            id  age  gender   bmi  daily_steps  sleep_hours  water_intake_l  \
# 99995   99996   53    Male  33.1         4726          3.9             2.0
# 99996   99997   22    Male  35.1        11554          4.5             3.1
# 99997   99998   37    Male  18.9         3924          3.8             1.0
# 99998   99999   72  Female  27.8        16110          5.6             0.8
# 99999  100000   37    Male  35.4         8222          9.1             1.8
#
#        calories_consumed  smoker  alcohol  resting_hr  systolic_bp  \
# 99995               3118       0        1          56          105
# 99996               1967       0        0          51          149
# 99997               2328       0        0          69           92
# 99998               3093       0        0          93          164
# 99999               3942       0        1          71          145
#
#        diastolic_bp  cholesterol  family_history  disease_risk
# ...

# %%
health_data.shape
# Out:
# (100000, 16)

# %%
health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 100000 non-null  int64
#  1   age                100000 non-null  int64
#  2   gender             100000 non-null  object
#  3   bmi                100000 non-null  float64
#  4   daily_steps        100000 non-null  int64
#  5   sleep_hours        100000 non-null  float64
#  6   water_intake_l     100000 non-null  float64
#  7   calories_consumed  100000 non-null  int64
#  8   smoker             100000 non-null  int64
#  9   alcohol            100000 non-null  int64
#  10  resting_hr         100000 non-null  int64
#  11  systolic_bp        100000 non-null  int64
#  12  diastolic_bp       100000 non-null  int64
#  13  cholesterol        100000 non-null  int64
#  14  family_history     100000 non-null  int64
# ...

# %%
health_data.describe()
# Out:
#                   id            age            bmi   daily_steps  \
# count  100000.000000  100000.000000  100000.000000  100000.00000
# mean    50000.500000      48.525990      29.024790   10479.87029
# std     28867.657797      17.886768       6.352666    5483.63236
# min         1.000000      18.000000      18.000000    1000.00000
# 25%     25000.750000      33.000000      23.500000    5729.00000
# 50%     50000.500000      48.000000      29.000000   10468.00000
# 75%     75000.250000      64.000000      34.500000   15229.00000
# max    100000.000000      79.000000      40.000000   19999.00000
#
#          sleep_hours  water_intake_l  calories_consumed         smoker  \
# count  100000.000000   100000.000000      100000.000000  100000.000000
# mean        6.491784        2.751496        2603.341200       0.200940
# std         2.021922        1.297338         807.288563       0.400705
# min         3.000000        0.500000        1200.000000       0.000000
# ...

# %%
health_data['bmi'].describe()
# Out:
# count    100000.000000
# mean         29.024790
# std           6.352666
# min          18.000000
# 25%          23.500000
# 50%          29.000000
# 75%          34.500000
# max          40.000000
# Name: bmi, dtype: float64

# %%
# Add a BMI outlier to a specific row (example: row index 0)
health_data.loc[0, "bmi"] = 120

# %%
p1=sb.boxplot(x=health_data['bmi'])

# %%
outliers = health_data[(health_data['bmi'] > 50) | (health_data['disease_risk'] < 20)]

# %%
outliers =['bmi']

# %%
health_data2=health_data[(health_data['bmi']<=50)]
p1=sb.boxplot(x=health_data2['bmi'])

# %%
health_data['disease_risk'].value_counts()
# Out:
# disease_risk
# 0    75179
# 1    24821
# Name: count, dtype: int64

# %%
# Check missing values before cleaning
print("Missing values before cleaning:")
print(health_data.isnull().sum())

# Fill missing numeric values with mean
health_data.fillna(health_data.mean(numeric_only=True), inplace=True)

# Fill missing categorical values with mode
health_data.fillna(health_data.mode().iloc[0], inplace=True)

# Check again after cleaning
print("\nMissing values after cleaning:")
print(health_data.isnull().sum())
# Out:
# Missing values before cleaning:
# id                   0
# age                  0
# gender               0
# bmi                  0
# daily_steps          0
# sleep_hours          0
# water_intake_l       0
# calories_consumed    0
# smoker               0
# alcohol              0
# resting_hr           0
# systolic_bp          0
# diastolic_bp         0
# cholesterol          0
# family_history       0
# disease_risk         0
# dtype: int64
#
# Missing values after cleaning:
# id                   0
# age                  0
# gender               0
# bmi                  0
# daily_steps          0
# sleep_hours          0
# water_intake_l       0
# calories_consumed    0
# smoker               0
# alcohol              0
# resting_hr           0
# systolic_bp          0
# diastolic_bp         0
# cholesterol          0
# family_history       0
# disease_risk         0
# dtype: int64

# %%
# Example: calculate total weekly exercise hours
health_data['WeeklyExercise'] = health_data['daily_steps'] * 7

# Example: simple health score (custom feature)
health_data['HealthScore'] = (health_data['sleep_hours'] * 10) - health_data['bmi']
health_data.head()
# Out:
#    id  age  gender    bmi  daily_steps  sleep_hours  water_intake_l  \
# 0   1   56    Male  120.0         4198          3.9             3.4
# 1   2   69  Female   33.3        14359          9.0             4.7
# 2   3   46    Male   31.6         1817          6.6             4.2
# 3   4   32  Female   38.2        15772          3.6             2.0
# 4   5   60  Female   33.6         6037          3.8             4.0
#
#    calories_consumed  smoker  alcohol  resting_hr  systolic_bp  diastolic_bp  \
# 0               1602       0        0          97          161           111
# 1               2346       0        1          68          116            65
# 2               1643       0        1          90          123            99
# 3               2460       0        0          71          165            95
# 4               3756       0        1          98          139            61
#
#    cholesterol  family_history  disease_risk  WeeklyExercise  HealthScore
# ...

# %%
# Add a new calculated column
health_data['BMI_Category'] = pd.cut(
health_data['bmi'],
bins=[0, 18.5, 24.9, 29.9, 100],
labels=['Underweight', 'Normal', 'Overweight', 'Obese']
)
health_data.head()
# Out:
#    id  age  gender    bmi  daily_steps  sleep_hours  water_intake_l  \
# 0   1   56    Male  120.0         4198          3.9             3.4
# 1   2   69  Female   33.3        14359          9.0             4.7
# 2   3   46    Male   31.6         1817          6.6             4.2
# 3   4   32  Female   38.2        15772          3.6             2.0
# 4   5   60  Female   33.6         6037          3.8             4.0
#
#    calories_consumed  smoker  alcohol  resting_hr  systolic_bp  diastolic_bp  \
# 0               1602       0        0          97          161           111
# 1               2346       0        1          68          116            65
# 2               1643       0        1          90          123            99
# 3               2460       0        0          71          165            95
# 4               3756       0        1          98          139            61
#
#    cholesterol  family_history  disease_risk  WeeklyExercise  HealthScore  \
# ...

# %%
health_data['BMI_Category'].value_counts().plot(
    kind='bar', color='lightgreen', edgecolor='black'
)
plt.title('Count of People by BMI Category')
plt.xlabel('BMI Category')
plt.ylabel('Count')
plt.show()

# %%
# Add a new calculated column
health_data['Age_Category'] = pd.cut(
health_data['age'],
bins=[0, 18, 35, 50, 65, 100],
labels=['Teen','Young Adult' , 'Middle Age', 'Senior', 'Elder']
)
health_data.head()
# Out:
#    id  age  gender    bmi  daily_steps  sleep_hours  water_intake_l  \
# 0   1   56    Male  120.0         4198          3.9             3.4
# 1   2   69  Female   33.3        14359          9.0             4.7
# 2   3   46    Male   31.6         1817          6.6             4.2
# 3   4   32  Female   38.2        15772          3.6             2.0
# 4   5   60  Female   33.6         6037          3.8             4.0
#
#    calories_consumed  smoker  alcohol  resting_hr  systolic_bp  diastolic_bp  \
# 0               1602       0        0          97          161           111
# 1               2346       0        1          68          116            65
# 2               1643       0        1          90          123            99
# 3               2460       0        0          71          165            95
# 4               3756       0        1          98          139            61
#
#    cholesterol  family_history  disease_risk  WeeklyExercise  HealthScore  \
# ...

# %%
health_data['Age_Category'].value_counts().plot(
    kind='bar', color='red', edgecolor='black'
)
plt.title('Count of People by Age Category')
plt.xlabel('Age Category')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(health_data['bmi'], bins=15, color='mediumseagreen', edgecolor='black', alpha=0.7)

plt.title('Distribution of BMI in the Dataset')
plt.xlabel('BMI')
plt.ylabel('Number of People')
plt.grid(axis='y', alpha=0.5)
plt.show()

# %%
bmi_by_gender = health_data.groupby('gender')['bmi'].mean()

bmi_by_gender.plot(kind='bar', color=['skyblue', 'lightcoral'])
plt.title('Average bmi by gender')
plt.xlabel('gender')
plt.ylabel('Average bmi')
plt.show()

# %%
smoker_counts = health_data['smoker'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(smoker_counts, labels=smoker_counts.index, autopct='%1.1f%%', startangle=90, colors=['lightcoral','skyblue'])
plt.title('Proportion of Smokers vs Non-Smokers')
plt.show()

# %%
# Scatter plot: age vs Systolic Blood Pressure
plt.figure(figsize=(8,6))
plt.scatter(health_data['age'], health_data['systolic_bp'], color='mediumseagreen', alpha=0.7)

# Add labels and title
plt.title('Relationship between AGE and Systolic Blood Pressure')
plt.xlabel('AGE')
plt.ylabel('Systolic Blood Pressure (mmHg)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(health_data['age'], health_data['diastolic_bp'], color='cornflowerblue', alpha=0.7)

plt.title('Relationship between AGE and Diastolic Blood Pressure')
plt.xlabel('AGE')
plt.ylabel('Diastolic Blood Pressure (mmHg)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(health_data['age'], health_data['systolic_bp'], color='red', alpha=0.6, label='Systolic BP')
plt.scatter(health_data['age'], health_data['diastolic_bp'], color='blue', alpha=0.6, label='Diastolic BP')

plt.title('AGE vs Blood Pressure (Systolic & Diastolic)')
plt.xlabel('age')
plt.ylabel('Blood Pressure (mmHg)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(health_data['cholesterol'], bins=15, color='cornflowerblue', edgecolor='black', alpha=0.7)

plt.title('Distribution of Cholesterol in the Dataset')
plt.xlabel('Cholesterol')
plt.ylabel('Number of People')
plt.grid(axis='y', alpha=0.5)
plt.show()

# %%
health_data['disease_risk'].value_counts().plot(
    kind='pie', autopct='%1.1f%%', colors=['lightcoral', 'gold', 'lightblue']
)
plt.title('Disease Risk Distribution')
plt.ylabel('')  # hide y-label
plt.show()

# %%
health_data.boxplot(column='sleep_hours', by='disease_risk', grid=False)
plt.title('Sleep Hours by Disease Risk')
plt.suptitle('')  # removes extra title
plt.xlabel('Disease Risk')
plt.ylabel('Sleep Hours')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
health_data['gender'] = le.fit_transform(health_data['gender'])

# %%
numeric_data = health_data.select_dtypes(include=['int64', 'float64'])

# %%
corr = numeric_data.corr()
corr
# Out:
#                          id       age    gender       bmi  daily_steps  \
# id                 1.000000 -0.001392  0.005690  0.000950     0.001470
# age               -0.001392  1.000000  0.000124  0.001262     0.004847
# gender             0.005690  0.000124  1.000000 -0.000223     0.001245
# bmi                0.000950  0.001262 -0.000223  1.000000     0.001633
# daily_steps        0.001470  0.004847  0.001245  0.001633     1.000000
# sleep_hours       -0.000693  0.000437 -0.003120  0.000721    -0.001209
# water_intake_l    -0.000532 -0.005644 -0.003173 -0.003552    -0.000898
# calories_consumed -0.004512 -0.002684 -0.000580  0.002066     0.000306
# smoker            -0.001161 -0.002455 -0.002921 -0.003481     0.000453
# alcohol            0.003285 -0.000923  0.004643  0.002034     0.003456
# resting_hr        -0.002270  0.001460 -0.001730 -0.006076     0.004401
# systolic_bp        0.001651  0.000806  0.002609  0.000964    -0.002049
# ...

# %%
# Plot heatmap
plt.figure(figsize=(10, 8))
sb.heatmap(
    corr,
    annot=True,            # show numbers
    cmap='coolwarm',       # color map
    fmt='.2f',             # 2 decimals in numbers
    annot_kws={"size":10},
    vmin=-1,               # min value for color scale
    vmax=1,                # max value for color scale
    cbar_kws={'shrink':0.8}
)

plt.title("Correlation Heatmap for Health Lifestyle Dataset", fontsize=10)
plt.xticks(rotation=45, ha='right',fontsize=10)
plt.yticks(rotation=0,fontsize=10)
plt.tight_layout()
plt.show()

# %%
f_corr = corr[(corr >= 0.5) | (corr <= -0.5)]
print(f_corr)
# Out:
#                     id  age  gender  bmi  daily_steps  sleep_hours  \
# id                 1.0  NaN     NaN  NaN          NaN          NaN
# age                NaN  1.0     NaN  NaN          NaN          NaN
# gender             NaN  NaN     1.0  NaN          NaN          NaN
# bmi                NaN  NaN     NaN  1.0          NaN          NaN
# daily_steps        NaN  NaN     NaN  NaN          1.0          NaN
# sleep_hours        NaN  NaN     NaN  NaN          NaN     1.000000
# water_intake_l     NaN  NaN     NaN  NaN          NaN          NaN
# calories_consumed  NaN  NaN     NaN  NaN          NaN          NaN
# smoker             NaN  NaN     NaN  NaN          NaN          NaN
# alcohol            NaN  NaN     NaN  NaN          NaN          NaN
# resting_hr         NaN  NaN     NaN  NaN          NaN          NaN
# systolic_bp        NaN  NaN     NaN  NaN          NaN          NaN
# diastolic_bp       NaN  NaN     NaN  NaN          NaN          NaN
# ...

# %%
from sklearn.feature_selection import chi2
from sklearn.preprocessing import LabelEncoder
data = health_data.copy()

cat_cols = ['gender', 'smoker', 'alcohol', 'family_history']

# Label encode categorical columns
le = LabelEncoder()
for col in cat_cols:
    data[col] = le.fit_transform(data[col])

# %%
X = data[cat_cols]            # categorical features
y = data['disease_risk']      # target

chi_scores, p_values = chi2(X, y)
chi_square_df = pd.DataFrame({
    'Feature': cat_cols,
    'Chi2_Score': chi_scores,
    'p_value': p_values
})

# %%
# Sort by chi-square score (highest first)
chi_square_df = chi_square_df.sort_values(by='Chi2_Score', ascending=False)
print(chi_square_df)
# Out:
#           Feature  Chi2_Score   p_value
# 3  family_history    0.729134  0.393164
# 0          gender    0.190943  0.662133
# 1          smoker    0.101082  0.750536
# 2         alcohol    0.018597  0.891529

# %%
# Visualization using matplotlib
plt.figure(figsize=(8,5))
plt.bar(chi_square_df['Feature'], chi_square_df['Chi2_Score'])
plt.xlabel("Feature")
plt.ylabel("Chi-Square Score")
plt.title("Chi-Square Feature Importance (Sorted)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample

# 1. Load Data
df = pd.read_csv('health_lifestyle_dataset.csv')

# 2. Feature Engineering
df['WeeklyExercise'] = df['daily_steps'] * 7
df['HealthScore'] = (df['sleep_hours'] * 10) - df['bmi']

# 3. Select Features
selected_features = [
    'age', 'gender', 'family_history', 'WeeklyExercise', 'cholesterol',
    'calories_consumed', 'resting_hr', 'diastolic_bp', 'water_intake_l',
    'sleep_hours', 'bmi', 'alcohol', 'HealthScore', 'daily_steps',
    'smoker', 'systolic_bp'
]
target = 'disease_risk'

X = df[selected_features].copy()
y = df[target]

# 4. Encode Categoricals
le = LabelEncoder()
X['gender'] = le.fit_transform(X['gender'])

# 5. BALANCE THE DATASET (Oversampling)
# Combine for resampling
data = pd.concat([X, y], axis=1)

# Separate classes
df_majority = data[data[target] == 0]
df_minority = data[data[target] == 1]

# Upsample minority class
df_minority_upsampled = resample(df_minority,
                                 replace=True,     # sample with replacement
                                 n_samples=len(df_majority),    # to match majority class
                                 random_state=42)

# Combine back
df_balanced = pd.concat([df_majority, df_minority_upsampled])

# 6. Train/Test Split on Balanced Data
X_balanced = df_balanced[selected_features]
y_balanced = df_balanced[target]

X_train, X_test, y_train, y_test = train_test_split(X_balanced, y_balanced, test_size=0.2, random_state=42)

# 7. Train Model
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

# 8. Evaluate
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))

clf_viz = DecisionTreeClassifier(random_state=42, max_depth=3)
clf_viz.fit(X_train, y_train)

# 8. Plot Decision Tree
plt.figure(figsize=(20, 10))
plot_tree(clf_viz,
          feature_names=selected_features,
          class_names=['No Risk', 'Risk'],
          filled=True,
          rounded=True,
          fontsize=12)
plt.title("Decision Tree Visualization (Top 3 Levels)")
plt.savefig('decision_tree_viz.png')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.72      0.81     15011
#            1       0.77      0.93      0.84     15061
#
#     accuracy                           0.83     30072
#    macro avg       0.84      0.83      0.82     30072
# weighted avg       0.84      0.83      0.82     30072

# %%
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample
# 8. Confusion Matrix
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

# 9. Plotting
plt.figure(figsize=(8, 6))
sb.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['No Risk', 'Disease Risk'],
            yticklabels=['No Risk', 'Disease Risk'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix (Balanced Data)')
plt.savefig('confusion_matrix_heatmap.png')

print("Confusion Matrix values:")
print(cm)
# Out:
# Confusion Matrix values:
# [[10853  4158]
#  [ 1050 14011]]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample

# 1. Load Data
df = pd.read_csv('health_lifestyle_dataset.csv')

# 2. Feature Engineering
df['WeeklyExercise'] = df['daily_steps'] * 7
df['HealthScore'] = (df['sleep_hours'] * 10) - df['bmi']

# 3. Select Features
selected_features = [
    'age', 'gender', 'family_history', 'WeeklyExercise', 'cholesterol',
    'calories_consumed', 'resting_hr', 'diastolic_bp', 'water_intake_l',
    'sleep_hours', 'bmi', 'alcohol', 'HealthScore', 'daily_steps',
    'smoker', 'systolic_bp'
]
target = 'disease_risk'

X = df[selected_features].copy()
y = df[target]

# 4. Preprocessing
le = LabelEncoder()
X['gender'] = le.fit_transform(X['gender'])

# 5. Balance Data (Upsampling)
data = pd.concat([X, y], axis=1)
df_majority = data[data[target] == 0]
df_minority = data[data[target] == 1]

df_minority_upsampled = resample(df_minority, replace=True, n_samples=len(df_majority), random_state=42)
df_balanced = pd.concat([df_majority, df_minority_upsampled])

# 6. Train/Test Split
X_balanced = df_balanced[selected_features]
y_balanced = df_balanced[target]
X_train, X_test, y_train, y_test = train_test_split(X_balanced, y_balanced, test_size=0.2, random_state=42)

# 7. Apply Naive Bayes
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# 8. Results
y_pred = gnb.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.5000665070497473
#               precision    recall  f1-score   support
#
#            0       0.50      0.53      0.51     15011
#            1       0.50      0.47      0.49     15061
#
#     accuracy                           0.50     30072
#    macro avg       0.50      0.50      0.50     30072
# weighted avg       0.50      0.50      0.50     30072

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.utils import resample

# 1. Load Data
df = pd.read_csv('health_lifestyle_dataset.csv')

# 2. Feature Engineering
df['WeeklyExercise'] = df['daily_steps'] * 7
df['HealthScore'] = (df['sleep_hours'] * 10) - df['bmi']

# 3. Select Features
selected_features = [
    'age', 'gender', 'family_history', 'WeeklyExercise', 'cholesterol',
    'calories_consumed', 'resting_hr', 'diastolic_bp', 'water_intake_l',
    'sleep_hours', 'bmi', 'alcohol', 'HealthScore', 'daily_steps',
    'smoker', 'systolic_bp'
]
target = 'disease_risk'

X = df[selected_features].copy()
y = df[target]

# 4. Preprocessing
le = LabelEncoder()
X['gender'] = le.fit_transform(X['gender'])

# 5. Balance Data (Upsampling)
data = pd.concat([X, y], axis=1)
df_majority = data[data[target] == 0]
df_minority = data[data[target] == 1]

df_minority_upsampled = resample(df_minority, replace=True, n_samples=len(df_majority), random_state=42)
df_balanced = pd.concat([df_majority, df_minority_upsampled])

# 6. Train/Test Split
X_balanced = df_balanced[selected_features]
y_balanced = df_balanced[target]
X_train, X_test, y_train, y_test = train_test_split(X_balanced, y_balanced, test_size=0.2, random_state=42)

# 7. Scale Features (Crucial for Logistic Regression)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 8. Train Logistic Regression
log_reg = LogisticRegression(random_state=42)
log_reg.fit(X_train_scaled, y_train)

# 9. Evaluate
y_pred = log_reg.predict(X_test_scaled)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.49866985900505456
#               precision    recall  f1-score   support
#
#            0       0.50      0.51      0.51     15011
#            1       0.50      0.48      0.49     15061
#
#     accuracy                           0.50     30072
#    macro avg       0.50      0.50      0.50     30072
# weighted avg       0.50      0.50      0.50     30072

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

# 1. Load & Prepare
df = pd.read_csv('health_lifestyle_dataset.csv')
df['WeeklyExercise'] = df['daily_steps'] * 7
df['HealthScore'] = (df['sleep_hours'] * 10) - df['bmi']

selected_features = [
    'age', 'gender', 'family_history', 'WeeklyExercise', 'cholesterol',
    'calories_consumed', 'resting_hr', 'diastolic_bp', 'water_intake_l',
    'sleep_hours', 'bmi', 'alcohol', 'HealthScore', 'daily_steps',
    'smoker', 'systolic_bp'
]
X = df[selected_features].copy()
le = LabelEncoder()
X['gender'] = le.fit_transform(X['gender'])

# 2. Scale (Crucial for K-Means)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Elbow Method
inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# 4. Apply K=2
kmeans = KMeans(n_clusters=2, random_state=42)
clusters = kmeans.fit_predict(X_scaled)

# 5. Visualize with PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
plt.scatter(X_pca[:,0], X_pca[:,1], c=clusters, cmap='viridis', alpha=0.5)
plt.show()

# %%
import pandas as pd
import joblib
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample

# 1. FORCE RELOAD DATA (This fixes the memory issue without restarting)
# We read from the file again to get fresh "Male"/"Female" text
df = pd.read_csv('health_lifestyle_dataset.csv')

# 2. Feature Engineering
df['WeeklyExercise'] = df['daily_steps'] * 7
df['HealthScore'] = (df['sleep_hours'] * 10) - df['bmi']

selected_features = [
    'age', 'gender', 'family_history', 'WeeklyExercise', 'cholesterol',
    'calories_consumed', 'resting_hr', 'diastolic_bp', 'water_intake_l',
    'sleep_hours', 'bmi', 'alcohol', 'HealthScore', 'daily_steps',
    'smoker', 'systolic_bp'
]
target = 'disease_risk'

X = df[selected_features].copy()
y = df[target]

# 3. SAFETY LOCK: Ensure gender is treated as text
X['gender'] = X['gender'].astype(str)

# 4. Train the Encoder on TEXT (Male/Female)
le = LabelEncoder()
X['gender'] = le.fit_transform(X['gender'])

# 5. Balance Data
data = pd.concat([X, y], axis=1)
df_majority = data[data[target] == 0]
df_minority = data[data[target] == 1]
df_minority_upsampled = resample(df_minority, replace=True, n_samples=len(df_majority), random_state=42)
df_balanced = pd.concat([df_majority, df_minority_upsampled])

# 6. Train Model
clf = DecisionTreeClassifier(random_state=42)
clf.fit(df_balanced[selected_features], df_balanced[target])

# 7. Overwrite the broken files
joblib.dump(clf, 'decision_tree_model.pkl')
joblib.dump(le, 'gender_encoder.pkl')

print("✅ FIXED: The encoder has been retrained on text ('Male'/'Female').")
print("👉 You can now run the GUI code block again.")
# Out:
# ✅ FIXED: The encoder has been retrained on text ('Male'/'Female').
# 👉 You can now run the GUI code block again.

# %%
# 1. Install Gradio (The GUI library)
# !pip install -q gradio

import pandas as pd
import gradio as gr
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample

print("🔄 resetting environment and training the Balanced Decision Tree...")

# --- STEP 1: LOAD & PREPARE DATA ---
try:
    df = pd.read_csv('health_lifestyle_dataset.csv')
except FileNotFoundError:
    print("❌ ERROR: Please upload 'health_lifestyle_dataset.csv' to Colab first!")
    raise

# 2. Feature Engineering (Exact formulas from your notebook)
df['WeeklyExercise'] = df['daily_steps'] * 7
df['HealthScore'] = (df['sleep_hours'] * 10) - df['bmi']

# 3. Define Features
features = [
    'age', 'gender', 'family_history', 'WeeklyExercise', 'cholesterol',
    'calories_consumed', 'resting_hr', 'diastolic_bp', 'water_intake_l',
    'sleep_hours', 'bmi', 'alcohol', 'HealthScore', 'daily_steps',
    'smoker', 'systolic_bp'
]
X = df[features].copy()
y = df['disease_risk']

# 4. Handle Gender (Force text to avoid 'int' errors)
X['gender'] = X['gender'].astype(str)
gender_encoder = LabelEncoder()
X['gender'] = gender_encoder.fit_transform(X['gender'])

# --- STEP 2: BALANCE THE DATA (CRITICAL STEP) ---
# We combine X and y to balance them together
train_data = pd.concat([X, y], axis=1)

# Separate Majority (Healthy) and Minority (Risk)
majority = train_data[train_data['disease_risk'] == 0]
minority = train_data[train_data['disease_risk'] == 1]

# Upsample Minority to match Majority count
minority_upsampled = resample(minority,
                              replace=True,
                              n_samples=len(majority),
                              random_state=42)

# Combine back together
df_balanced = pd.concat([majority, minority_upsampled])

print(f"✅ Data Balanced: {len(df_balanced)} samples total (50% Risk / 50% Healthy)")

# --- STEP 3: TRAIN THE DECISION TREE ---
model = DecisionTreeClassifier(random_state=42)
model.fit(df_balanced[features], df_balanced['disease_risk'])
print("🧠 Decision Tree Trained Successfully!")

# --- STEP 4: THE GUI ---
def predict_risk(age, gender, bmi, steps, sleep, calories, water, sys_bp, dia_bp, hr, chol, family, smoke, alc):
    # 1. Recreate the hidden features
    weekly_ex = steps * 7
    h_score = (sleep * 10) - bmi

    # 2. Encode inputs (Text -> Numbers)
    gender_code = gender_encoder.transform([gender])[0]
    fam_code = 1 if family == "Yes" else 0
    smoke_code = 1 if smoke == "Yes" else 0
    alc_code = 1 if alc == "Yes" else 0

    # 3. Create DataFrame (MUST match feature order exactly)
    input_df = pd.DataFrame([[
        age, gender_code, fam_code, weekly_ex, chol,
        calories, hr, dia_bp, water, sleep, bmi,
        alc_code, h_score, steps, smoke_code, sys_bp
    ]], columns=features)

    # 4. Predict
    prediction = model.predict(input_df)[0]

    # 5. Return Result
    if prediction == 1:
        return "⚠️ HIGH RISK DETECTED\nThe model suggests a high likelihood of disease."
    else:
        return "✅ LOW RISK (Healthy)\nThe model suggests you are in the safe zone."

# Launch the App
app = gr.Interface(
    fn=predict_risk,
    inputs=[
        gr.Slider(18, 100, value=30, label="Age"),
        gr.Dropdown(["Male", "Female"], label="Gender"),
        gr.Slider(15, 50, value=25, label="BMI (Normal is 18-25)"),
        gr.Slider(0, 25000, value=6000, label="Daily Steps"),
        gr.Slider(3, 12, value=7, label="Sleep Hours"),
        gr.Slider(1000, 5000, value=2500, label="Calories Consumed"),
        gr.Slider(0.5, 5.0, value=2.0, label="Water Intake (L)"),
        gr.Slider(90, 200, value=120, label="Systolic BP (Top)"),
        gr.Slider(60, 120, value=80, label="Diastolic BP (Bottom)"),
        gr.Slider(40, 120, value=72, label="Heart Rate"),
        gr.Slider(100, 400, value=200, label="Cholesterol (Normal < 200)"),
        gr.Radio(["Yes", "No"], label="Family History?"),
        gr.Radio(["Yes", "No"], label="Smoker?"),
        gr.Radio(["Yes", "No"], label="Alcohol Consumer?")
    ],
    outputs="text",
    title="🩺 Balanced Decision Tree Predictor",
    description="This model is trained on the BALANCED dataset (83% Accuracy). Adjust sliders to see High vs Low risk."
)

app.launch(share=True)
# Out:
# 🔄 resetting environment and training the Balanced Decision Tree...
# ✅ Data Balanced: 150358 samples total (50% Risk / 50% Healthy)
# 🧠 Decision Tree Trained Successfully!
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://61fe0107aefbf0c082.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://61fe0107aefbf0c082.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# ---------------------------
# 5. Select significant categorical features (or keep all if none)
# ---------------------------
alpha = 0.05
cat_selected = chi_square_df[chi_square_df['p_value'] < alpha]['Feature'].tolist()

if not cat_selected:
    print("\nNo categorical features are statistically significant. Keeping all categorical features for training.")
    cat_selected = cat_cols.copy()
else:
    print("\nSelected categorical features based on chi-square:")
print(cat_selected)

# ---------------------------
# 6. Combine with numerical features
# ---------------------------
# Ensure numerical columns are a list and exclude target and 'id'
num_cols = numeric_data.columns.tolist()
clean_num_cols = [col for col in num_cols if col not in ['id', 'disease_risk']]

# Combine numerical + categorical features, remove duplicates
final_selected_features = list(set(clean_num_cols + cat_selected))

print("\n==============================")
print("FINAL SELECTED FEATURES")
print("==============================")
print(final_selected_features)
# Out:
# No categorical features are statistically significant. Keeping all categorical features for training.
# ['gender', 'smoker', 'alcohol', 'family_history']
#
# ...
# FINAL SELECTED FEATURES
# ...
# ['age', 'gender', 'family_history', 'WeeklyExercise', 'cholesterol', 'calories_consumed', 'resting_hr', 'diastolic_bp', 'water_intake_l', 'sleep_hours', 'bmi', 'alcohol', 'HealthScore', 'daily_steps', 'smoker', 'systolic_bp']

# %%
from sklearn.preprocessing import StandardScaler

columns_to_scale = [
    'age',
    'bmi',
    'daily_steps',
    'sleep_hours',
    'water_intake_l',
    'calories_consumed',
    'resting_hr',
    'systolic_bp',
    'diastolic_bp',
    'cholesterol'
]

# Initialize the scaler
scaler = StandardScaler()

# Fit and transform all of them at once
health_data[columns_to_scale] = scaler.fit_transform(health_data[columns_to_scale])

# Now all your features are standardized!
print(health_data[columns_to_scale].describe())
